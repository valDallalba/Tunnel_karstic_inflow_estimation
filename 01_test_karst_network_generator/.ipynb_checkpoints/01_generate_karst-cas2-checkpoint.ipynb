# %% [markdown]
# # Generates conduit networks with PyKasso for the NAGRA project
#
# The conceptual model is a vertical cross section, and the tunnel is on the bottom left side. Dimension of the model is to be precised in the following cell
# This version of the code generates inputs file to be used with step2 code.
# August 2020.

# %%
import pykasso as pk
import numpy as np
import matplotlib.pyplot as plt
import yaml
import os

# %%
exec(open('function_generate_karst.py').read())

# %% [markdown]
# ### Model Caracteristics
#
# In the first cell we define our model caracteristics. In the second cell, we generate some matrix that will be needed later

# %%
dim_x, dim_z = 2000, 200 #Dimension in M
cell_x, cell_z = 1, 1 #Cell dimension in X and Z

# %%
nagra = Karst_networks(cell_x,cell_z,dim_x,dim_z)
surface_inlets = 40
side_inlets = 12
random_inlets = 40
#number beddings
n_beddings = 30
#outlet(s) position(s)
x_o = 5
z_o = 5

nagra.set_karst_input(surface_inlets,side_inlets,[[x_o,z_o]])
# Out:
# Outlets redefined

# %% [markdown]
# ## Karst Caracteristics

# %% [markdown]
# We then generate the configuration file for PyKasso. The details of the parameters are outlines in the hidden cell below

# %% [raw]
#  ##################
# ### SKS SETTINGS ###
#  ##################
#
# ---
# ############
# ### Grid ###
# ############
#
# x0   : 0
# y0   : 0
# xnum : 401
# ynum : 101
# dx   : 5
# dy   : 5
#
# ###############
# ### Polygon ###
# ###############
#
# data_has_polygon : False
# polygon_data     : 'inputs/polygon.txt'
#
# ####################
# ### PointManager ###
# ####################
#
# ###Inlets
# # 'random'    - full random points
# # 'import'    - import points
# # 'composite' - add n random points to imported points
# inlets_mode   : 'composite'
# inlets_data   : 'inputs/points.csv'
# inlets_number : 0
#
# ###Outlets
# # 'random'    - full random points
# # 'import'    - import points
# # 'composite' - add n random points to imported points
# outlets_mode   : 'import'
# outlets_data   : 'inputs/outlets.csv'
# outlets_number : 1
#
# ######################
# ### GeologyManager ###
# ######################
#
# ###Geology
# # 'null'   - No geology
# # 'import' - Import geology
# # 'image'  - Import geology via image
# geological_mode     : 'null'
# #geological_datafile : 'inputs/betteraz_2D_z430.gslib'
#
# ###Faults
# # 'null'   - No faults
# # 'import' - Import faults
# # 'image'  - Import faults via image
# faults_mode     : 'null'
# #faults_datafile : 'inputs/betteraz_fault_20_2D.gslib'
#
# ###Fractures
# # 'null'   - No fractures
# # 'import' - Import fractures
# # 'image'  - Import fractures via image
# # 'random' - Generate random fractures
# fractures_mode     : 'random'
# #fractures_datafile : 'inputs/betteraz_fault_20_2D.gslib'
#
# # If fractures mode is 'generate'
# #fractures_densities       : [5.83e-6,1.38e-6,2.22e-6,2.5e-6,4.16e-6,6.66e-6,5e-6]
# #fractures_min_orientation : [      0,     15,     30,    60,    105,    120, 150]
# #fractures_max_orientation : [     15,     30,     45,   105,    120,    150, 180]
# fractures_densities       : [1e-4,8e-5,8e-5,8e-4]
# fractures_min_orientation : [     -5,     25,     -30,    89]
# fractures_max_orientation : [      5,     30,     -25,    91]
#
# # For fracture size
# alpha : 1.7
# fractures_min_length : 10
# fractures_max_length : 3000
# #fractures_min_length : [100, 100, 100, 100]
# #fractures_max_length : [8500, 6000, 6000,6000]
#
# ###############################
# ### Fast-Marching Algorithm ###
# ###############################
#
# code_out       : 0.1
# code_aquifere  : 2
# code_aquiclude : 1
# code_faults    : 4
# code_fractures : 4 # je l'ai augmenté à 4 pour avoir plus de contraste
# code_conduits  : 5
#
# ### Formation to consider and FMM code associated
# geology_id       : [1,2] # Only for 'import' geological mode
# geology_velocity : [code_aquifere,code_aquiclude]
#
# importance_factor : [1,2,4]
#
# #############
# ### Other ###
# #############
#
# # if 0 = total random
# rand_seed : 1
# ...

# %%
Parameters_PyKart = {
"x0": 0,
"y0": 0,
"xnum" : nagra.nx,
"ynum" : nagra.ny,
"dx"   : cell_x,
"dy"   : cell_z,
"inlets_mode"   : 'composite',
"inlets_data"   : 'model_info/points_in.csv',
"inlets_number" : random_inlets,
"outlets_mode"   : 'composite',
"outlets_data"   : 'model_info/points_out.csv',
"outlets_number" : 0,
"geological_mode"     : 'null',
"faults_mode"    : 'null',
"fractures_mode"     : 'random',
"fractures_densities"       : [1e-4,8e-4,8e-4,1e-4],
"fractures_min_orientation" : [-5, 25, -30, 85],
"fractures_max_orientation" : [5, 30, -25, 95],
"alpha" : 1.7,
"fractures_min_length" : [200, 100, 100, 200],
"fractures_max_length" : [4000, 500, 500,4000],
"code_out"       : 0.1,
"code_aquifere"  : 2,
"code_aquiclude" : 1,
"code_faults"    : 4,
"code_fractures" : 4, # je l'ai augmenté à 4 pour avoir plus de contraste
"code_conduits"  : 5,
"geology_id"       : [1,2], # Only for 'import' geological mode
"geology_velocity" : ['code_aquifere','code_aquiclude'],
"importance_factor" : [1,2],
"data_has_polygon" : False,
"rand_seed" : 123456789,
}

nagra.set_pykasso_param(Parameters_PyKart)
nagra.run_pykasso_sks()
# Out:
# Pykasso parameters are sets!
# Pykasso SKS is done!

# %%
nagra.add_bed_fractures(n_beddings)
nagra.plot_fractures()

nagra.sks.compute_karst_network() #gradient simulation
nagra.plot_karst()
# Out:
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd

# %% [markdown]
# ## Loop and Exports

# %%
n_sims = 50
init_seed = 987654331
seeds = range(init_seed,init_seed+n_sims)

# %%
try:
    os.mkdir('pykasso_networks') #create the folder if it doesn't exists
except:
    print('Folder already exists')  
    
for seed in seeds:
    nagra.set_karst_input(surface_inlets,side_inlets,[[x_o,z_o]])   
    nagra.update(seed) #recalculate the fractures
    nagra.add_bed_fractures(n_beddings)
    nagra.sks.compute_karst_network() #gradient simulation
    print('------------ \n')
    print(str(seed-init_seed+1) + ' simulations')
    print('------------ \n')
    #nagra.plot_karst()
    nagra.export(seed,'cas2')
# Out:
# Folder already exists
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 1 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 2 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 3 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 4 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 5 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 6 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 7 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 8 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 9 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 10 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 11 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 12 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 13 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 14 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 15 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 16 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 17 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 18 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 19 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 20 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 21 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 22 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 23 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 24 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 25 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 26 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 27 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 28 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 29 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 30 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 31 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 32 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 33 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 34 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 35 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 36 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 37 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 38 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 39 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 40 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 41 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 42 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 43 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 44 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 45 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 46 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 47 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 48 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 49 simulations
# ------------
#
#
# Outlets redefined
# Warning: This network contains  0 looping branches Tortuosity is infinite on a looping branch. It is set to NAN to avoid further errors.
#
# Computing:
#  - mean length,cv length,length entropy,mean tortuosity
#  - orientation entropy,aspl,cpd,md,cv degree,cvd
# ------------
#
# 50 simulations
# ------------
