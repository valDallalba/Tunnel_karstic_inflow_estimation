# %% [markdown]
# ## MF5 cfp Karst simulation

# %%
import pandas as pd
import flopy as fp
from flopy.utils.gridintersect import GridIntersect
# Out:
# flopy is installed in c:\users\wdall\anaconda3\envs\nagra_2020\lib\site-packages\flopy

# %%
from generate_karst_functions.function_cfp_run import *

# %%
exec(open('function_cfp_run.py').read())

# %% [markdown]
# ### Set mf5 model

# %%
fp.modflow.ModflowPcg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-15f7980cbd2d> in <module>
# ----> 1 fp.modflow.ModflowPcg()
#
# TypeError: __init__() missing 1 required positional argument: 'model'

# %%
model_fp = Model_cfp()
# Out:
# *** Model is initialized! 0 ***

# %%
sx = 2
sy = 2
nx = int(2000/sx)
ny = int(200/sy)

# %%
model_fp.set_dimension(nrow=ny,ncol=nx,delc=sx,delr=sy,zbot=-2)
model_fp.set_time_periode()
model_fp.init_discretization()
# Out:
# Dimensions are set! 1
# Time period is set! 2
# *** Model is discretized! 3 ***

# %% [markdown]
# ### Set Initial condition and boundary condition

# %%
out_position = np.loadtxt('pykasso_networks_simply_cfp/cas_1_123456789/tunnel_info.txt')
out_x = int(out_position[0])
out_y = int(out_position[1])
out_node = int(out_position[2])

# %%
out_position, out_x, out_y
# Out:
# (array([  92.,   13., 2984.]), 92, 13)

# %%
model_fp.set_bdc_type()
model_fp.set_bdc_val()
model_fp.set_bdc_val(matrix_ini_bdc=True, val=head)
#<0 = cst head
#Top
model_fp.bdc_type[0,-1,:] = -1
model_fp.bdc_val[0,-1,:]  = 450.
#Tunnel
model_fp.bdc_type[0,out_y,out_x] = -1
model_fp.bdc_val[0,out_y,out_x]  = 0
model_fp.init_bdc()
model_fp.set_flow_prop()
model_fp.init_flow_prop()
# Out:
# Boundary cell types are set! 4
# Boundary cell values are set! 5
# Boundary cell values are set! 5
# *** Boundary conditions are initialized! 6 ****
# Flow properties are defined! 7
# *** Flow properties are initialized! 8 ***

# %% [markdown]
# ### Set matrix properties

# %%
model_fp.set_flow_prop()
model_fp.init_flow_prop()
# Out:
# Flow properties are defined! 7
# *** Flow properties are initialized! 8 ***

# %% [markdown]
# ### Set output control files

# %%
model_fp.init_output_control()
# Out:
# *** Output control parameters are initialized! 9 ***

# %% [markdown]
# ### Set cfp properties

# %%
path_file_cfp = 'pykasso_networks_simply_cfp/cas_1_123456789/' #path to the pykasso input files
model_fp.set_cfp_node_oc(path_file_cfp)
model_fp.init_cfp_node_oc(1,[out_node+1],0,[model_fp.nb_pipe])
# Out:
# Output control nodes are set! 10
# *** Output control nodes are initialized! 11 ***

# %%
model_fp.set_conduit_recharge_prop()
model_fp.init_conduit_recharge_prop()
model_fp.set_conduit_flow_prop()
model_fp.init_conduit_flow_prop()
# Out:
# Conduit recharge properties are set! 12
# *** Conduit recharge properties are initialized 13 ***
# Conduit flow properties are set! 14
# *** Conduit flow properties are initialized! 15***

# %% [markdown]
# ### Write input file

# %%
model_fp.write_input_files()
# Out:
# *** Input files are written! 16***

# %% [markdown]
# ### Update input file for cfp

# %%
model_fp.update_input_files()
# Out:
# *** Input files are modified! 17***

# %% [markdown]
# ### Run simulation and clean repository

# %%
model_fp.model.run_model()
model_fp.clean_repo()
# Out:
# FloPy is using the following  executable to run the model: .\mf2005cfp.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.8.00_cfp 02/23/2011
#
#  Using NAME file: model_mf5cfp.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/08/27 17:19:17
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
# forrtl: severe (170): Program Exception - stack overflow
# Image              PC        Routine            Line        Source
# mf2005cfp.exe      00CA8CD7  Unknown               Unknown  Unknown
# mf2005cfp.exe      0084785C  _GWF2CFP1M1FM            3059  gwf2cfp1elk.f
# mf2005cfp.exe      009EB28E  _MAIN__                   297  mf2005.f
# mf2005cfp.exe      00D0A373  Unknown               Unknown  Unknown
# mf2005cfp.exe      00CA9187  Unknown               Unknown  Unknown
# mf2005cfp.exe      00CA905F  Unknown               Unknown  Unknown
# KERNEL32.DLL       767A6359  Unknown               Unknown  Unknown
# ntdll.dll          77437C24  Unknown               Unknown  Unknown
# ntdll.dll          77437BF4  Unknown               Unknown  Unknown
# Repository is clean!

# %%
head = model_fp.plot_heads('mf5_cfp_files/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-ca95a8e1bfa1> in <module>
# ----> 1 head = model_fp.plot_heads('mf5_cfp_files/')
#
# <string> in plot_heads(self, path)
#
# c:\users\wdall\anaconda3\envs\nagra_2020\lib\site-packages\flopy\utils\binaryfile.py in __init__(self, filename, text, precision, verbose, **kwargs)
#     456         self.text = text.encode()
#     457         if precision == 'auto':
# --> 458             precision = get_headfile_precision(filename)
#     459             if precision == 'unknown':
#     460                 s = 'Error. Precision could not be determined for {}'.format(
#
# c:\users\wdall\anaconda3\envs\nagra_2020\lib\site-packages\flopy\utils\binaryfile.py in get_headfile_precision(filename)
#     209     assert f.tell() == 0
#     210     if totalbytes == 0:
# --> 211         raise IOError('datafile error: file is empty: ' + str(filename))
#     212
#     213     # first try single
#
# OSError: datafile error: file is empty: mf5_cfp_files/model_mf5cfp.hds

# %%
head.shape
# Out:
# (100, 1000)

# %%
head.shape
# Out:
# (1, 50, 125)

# %% [markdown]
# ## Do not run below

# %% [markdown]
# ### Some plots

# %% [markdown]
# sx = 1
# temps = 12 s

# %%
head = model_fp.plot_heads('mf5_cfp_files/')

# %% [markdown]
# sx = 2
# tmps = 1.8s

# %%
head = model_fp.plot_heads('mf5_cfp_files/')

# %% [markdown]
# sx = 5
# temps = 0.13 sec

# %%
head = model_fp.plot_heads('mf5_cfp_files/')

# %%
head = model_fp.plot_heads('mf5_cfp_files/')

# %%
np.savetxt('test_resolution/sx_2_big/sx_2_head.txt',head[0])

# %% [markdown]
# ### To visualise the network shape and output position (manual)

# %%
network = np.zeros((int(nx),int(ny)))
i = 0
nb = 123456789
path_output_simplification = 'pykasso_networks_simply/'
node_name = path_output_simplification+'nodes_cas1_123456789_simply.txt'
nodes = np.loadtxt(node_name)[:,1:]
for n in nodes:
    network[int(n[1]/sx),int(n[0]/sy)] = 1

# %%
plt.imshow(network, origin='bot')
plt.plot(out_x, out_y,'or')
plt.show()
